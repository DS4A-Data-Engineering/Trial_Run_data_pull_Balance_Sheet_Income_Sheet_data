# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
wiki_data=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies') #Open the link and download S&P company details in a tabl

# %%
wiki_data
# Out:
# [    Symbol              Security             GICS Sector  \
#  0      MMM                    3M             Industrials
#  1      AOS           A. O. Smith             Industrials
#  2      ABT                Abbott             Health Care
#  3     ABBV                AbbVie             Health Care
#  4      ACN             Accenture  Information Technology
#  ..     ...                   ...                     ...
#  498    YUM           Yum! Brands  Consumer Discretionary
#  499   ZBRA    Zebra Technologies  Information Technology
#  500    ZBH         Zimmer Biomet             Health Care
#  501   ZION  Zions Bancorporation              Financials
#  502    ZTS                Zoetis             Health Care
#
#                        GICS Sub-Industry    Headquarters Location  Date added  \
#  0              Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
#  1                     Building Products     Milwaukee, Wisconsin  2017-07-26
# ...

# %%
wiki_data[1]
# Out:
#                   Date  Added                                Removed  \
#                   Date Ticker                       Security  Ticker
# 0          May 4, 2023   AXON                Axon Enterprise     FRC
# 1       March 20, 2023   FICO                     Fair Isaac    LUMN
# 2       March 15, 2023     BG                  Bunge Limited    SBNY
# 3       March 15, 2023   PODD                        Insulet    SIVB
# 4      January 5, 2023    NaN                            NaN     VNO
# ..                 ...    ...                            ...     ...
# 319       June 9, 1999    WLP                      Wellpoint     HPH
# 320  December 11, 1998    FSR                        Firstar     LDW
# 321  December 11, 1998    CCL                 Carnival Corp.     GRN
# 322  December 11, 1998   CPWR                      Compuware     SUN
# 323      June 17, 1997    CCI  Countrywide Credit Industries     USL
#
#                                \
#                      Security
# ...

# %%
wiki_data[0]
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1                     Building Products     Milwaukee, Wisconsin  2017-07-26
# ...

# %%
data = wiki_data[0] # All data is stored in first cell

# %%
display(data.head()) # print to check data downloaded
# Out:
#   Symbol     Security             GICS Sector               GICS Sub-Industry  \
# 0    MMM           3M             Industrials        Industrial Conglomerates
# 1    AOS  A. O. Smith             Industrials               Building Products
# 2    ABT       Abbott             Health Care           Health Care Equipment
# 3   ABBV       AbbVie             Health Care                 Pharmaceuticals
# 4    ACN    Accenture  Information Technology  IT Consulting & Other Services
#
#      Headquarters Location  Date added      CIK      Founded
# 0    Saint Paul, Minnesota  1957-03-04    66740         1902
# 1     Milwaukee, Wisconsin  2017-07-26    91142         1916
# 2  North Chicago, Illinois  1957-03-04     1800         1888
# 3  North Chicago, Illinois  2012-12-31  1551152  2013 (1888)
# 4          Dublin, Ireland  2011-07-06  1467373         1989

# %%
sorted_data = data.sort_values(by=['Symbol'], ascending=True) #Sort the dataframe on ticker in alphabetical ascending order
sorted_data
# Out:
#     Symbol                 Security             GICS Sector  \
# 12       A     Agilent Technologies             Health Care
# 29     AAL  American Airlines Group             Industrials
# 9      AAP       Advance Auto Parts  Consumer Discretionary
# 44    AAPL               Apple Inc.  Information Technology
# 3     ABBV                   AbbVie             Health Care
# ..     ...                      ...                     ...
# 498    YUM              Yum! Brands  Consumer Discretionary
# 500    ZBH            Zimmer Biomet             Health Care
# 499   ZBRA       Zebra Technologies  Information Technology
# 501   ZION     Zions Bancorporation              Financials
# 502    ZTS                   Zoetis             Health Care
#
#                               GICS Sub-Industry    Headquarters Location  \
# 12                        Health Care Equipment  Santa Clara, California
# 29                           Passenger Airlines        Fort Worth, Texas
# ...

# %%
sorted_data['GICS Sector'].value_counts()
# Out:
# Industrials               74
# Financials                72
# Information Technology    66
# Health Care               65
# Consumer Discretionary    53
# Consumer Staples          37
# Utilities                 30
# Real Estate               30
# Materials                 29
# Communication Services    24
# Energy                    23
# Name: GICS Sector, dtype: int64

# %%
#finance_sorted_data = sorted_data[sorted_data['GICS Sector'] == 'Financials']
bank_finance_sorted_data = finance_sorted_data[finance_sorted_data['GICS Sub-Industry'].str.contains('Banks', na=False)]

# %%
bank_finance_sorted_data['Security']
# Out:
# 35              Ameriprise Financial
# 60                   Bank of America
# 211               Franklin Templeton
# 71                        BNY Mellon
# 70                         BlackRock
# 114                        Citigroup
# 115         Citizens Financial Group
# 123                         Comerica
# 199                 Fifth Third Bank
# 245            Huntington Bancshares
# 262                          Invesco
# 271                   JPMorgan Chase
# 275                          KeyCorp
# 298                         M&T Bank
# 345                   Northern Trust
# 378           PNC Financial Services
# 401    Regions Financial Corporation
# 428         State Street Corporation
# 455                           Truist
# 436                    T. Rowe Price
# 458                        U.S. Bank
# 485                      Wells Fargo
# 501             Zions Bancorporation
# Name: Security, dtype: object

# %%
bank_finance_sorted_data
# Out:
#     Symbol                       Security GICS Sector  \
# 35     AMP           Ameriprise Financial  Financials
# 60     BAC                Bank of America  Financials
# 211    BEN             Franklin Templeton  Financials
# 71      BK                     BNY Mellon  Financials
# 70     BLK                      BlackRock  Financials
# 114      C                      Citigroup  Financials
# 115    CFG       Citizens Financial Group  Financials
# 123    CMA                       Comerica  Financials
# 199   FITB               Fifth Third Bank  Financials
# 245   HBAN          Huntington Bancshares  Financials
# 262    IVZ                        Invesco  Financials
# 271    JPM                 JPMorgan Chase  Financials
# 275    KEY                        KeyCorp  Financials
# 298    MTB                       M&T Bank  Financials
# 345   NTRS                 Northern Trust  Financials
# 378    PNC         PNC Financial Services  Financials
# ...

# %%
#import os

#new_dir_path = 'data'

#os.mkdir(new_dir_path)

# %%
# Convert the dataframe to csv file
bank_finance_sorted_data.to_csv('data/S&P500_bank_Tickers.csv', mode='w', index=False) #index is False as we don't want to write index in csv file
